# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Data loading

# %%
# For SKUs starting with '90'
# Data loading
df = pd.read_csv('../data/ForecastDataset_from_2016_to_2025_for_SKUs_started_with_90.csv')

# %%
df.shape
# Out:
# (533948, 9)

# %%
df.head()
# Out:
#   ProductFamily  Order_ID   OrderDate          SKU_Description  \
# 0          AIRD  62181848  12/19/2022        Air Doctor AD3000
# 1          AIRD  60849149    7/8/2021  Air Doctor AD1000 Tower
# 2          AIRD  60849335    7/8/2021        Air Doctor AD3000
# 3          AIRD  60849349    7/8/2021        Air Doctor AD3000
# 4          AIRD  60849449    7/8/2021        Air Doctor AD3000
#
#    WareHouseQuantity           SKU SKU_Category            Channel ShipToState
# 0                  1    90AD01AD01   Cross Sell         SEM_Radial          VA
# 1                  1  90AD01AT01-W         Unit   DIG_OTHER_Radial          PA
# 2                  1    90AD01AD01   Cross Sell         WEB_Radial          OR
# 3                  1    90AD01AD01   Cross Sell         WEB_Radial          MT
# 4                  1    90AD01AD01   Cross Sell  DIG_INFLCR_Radial          MD

# %%
df.columns
# Out:
# Index(['ProductFamily', 'Order_ID', 'OrderDate', 'SKU_Description',
#        'WareHouseQuantity', 'SKU', 'SKU_Category', 'Channel', 'ShipToState'],
#       dtype='object')

# %%
df.nunique()
# Out:
# ProductFamily             1
# Order_ID             479881
# OrderDate              3103
# SKU_Description          20
# WareHouseQuantity        13
# SKU                      21
# SKU_Category              3
# Channel                  34
# ShipToState              88
# dtype: int64

# %%
df.isna().sum()
# Out:
# ProductFamily          0
# Order_ID               0
# OrderDate              0
# SKU_Description      544
# WareHouseQuantity      0
# SKU                    0
# SKU_Category         544
# Channel               12
# ShipToState           92
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (533300, 9)

# %% [markdown]
# ### Feature Engineering

# %%
df['OrderDate'] = pd.to_datetime(df['OrderDate'])
df['Week'] = df['OrderDate'].dt.to_period('W').apply(lambda r: r.start_time)
df['Month'] = df['OrderDate'].dt.month
df['Year'] = df['OrderDate'].dt.year

# %%
df.head()
# Out:
#   ProductFamily  Order_ID  OrderDate          SKU_Description  \
# 0          AIRD  62181848 2022-12-19        Air Doctor AD3000
# 1          AIRD  60849149 2021-07-08  Air Doctor AD1000 Tower
# 2          AIRD  60849335 2021-07-08        Air Doctor AD3000
# 3          AIRD  60849349 2021-07-08        Air Doctor AD3000
# 4          AIRD  60849449 2021-07-08        Air Doctor AD3000
#
#    WareHouseQuantity           SKU SKU_Category            Channel  \
# 0                  1    90AD01AD01   Cross Sell         SEM_Radial
# 1                  1  90AD01AT01-W         Unit   DIG_OTHER_Radial
# 2                  1    90AD01AD01   Cross Sell         WEB_Radial
# 3                  1    90AD01AD01   Cross Sell         WEB_Radial
# 4                  1    90AD01AD01   Cross Sell  DIG_INFLCR_Radial
#
#   ShipToState       Week  Month  Year
# 0          VA 2022-12-19     12  2022
# 1          PA 2021-07-05      7  2021
# 2          OR 2021-07-05      7  2021
# 3          MT 2021-07-05      7  2021
# 4          MD 2021-07-05      7  2021

# %% [markdown]
# ### Range Of SKU's

# %%
def print_date_ranges(df, sku_list=None):
    """
    Prints the overall dataset date range and individual date ranges for specified SKUs.

    Parameters:
    df (pd.DataFrame): DataFrame containing at least 'OrderDate' and 'SKU' columns.
    sku_list (list, optional): List of SKU strings to check date ranges for.
    """
    print("Full dataset date range:", df['OrderDate'].min(), "to", df['OrderDate'].max())
    
    if sku_list:
        for sku in sku_list:
            df_sku_check = df[df['SKU'] == sku]
            if not df_sku_check.empty:
                print(f"Selected SKU date range {sku}:", df_sku_check['OrderDate'].min(), "to", df_sku_check['OrderDate'].max())
                # print(f"Total weekly data points for this SKU: {df_sku_check.shape[0]}")
            else:
                print(f"No data found for SKU: {sku}")

# %%
sku_list = ['90AD350AD01', '90AD200AD01', '90AD01AT01-W', '90AD02AD01', '90AD550AD01']
print_date_ranges(df, sku_list)
# Out:
# Full dataset date range: 2016-12-23 00:00:00 to 2025-07-29 00:00:00
# Selected SKU date range 90AD350AD01: 2022-09-15 00:00:00 to 2025-07-29 00:00:00
# Selected SKU date range 90AD200AD01: 2022-06-04 00:00:00 to 2025-07-28 00:00:00
# Selected SKU date range 90AD01AT01-W: 2019-08-16 00:00:00 to 2025-07-28 00:00:00
# Selected SKU date range 90AD02AD01: 2021-05-25 00:00:00 to 2023-06-30 00:00:00
# Selected SKU date range 90AD550AD01: 2022-09-15 00:00:00 to 2025-07-28 00:00:00

# %% [markdown]
# ### Data Splitting: Training and Testing (For Checking Accuracy)
# - For Testing : April, May, June 2025
# - For Training : Sep 22 to March 31

# %%
import pandas as pd
from dateutil.relativedelta import relativedelta


# Convert OrderDate to datetime
df['OrderDate'] = pd.to_datetime(df['OrderDate'])

# Create 'Week' column as week start date (Monday)
df['Week'] = df['OrderDate'].dt.to_period('W').apply(lambda r: r.start_time)

# Group weekly by SKU
weekly_by_sku = df.groupby(['Week', 'SKU'])['WareHouseQuantity'].sum().reset_index()

# Filter for the specific SKU
sku = '90AD350AD01'
# sku = '90AD200AD01'
df_sku_weekly = weekly_by_sku[weekly_by_sku['SKU'] == sku][['Week', 'WareHouseQuantity']].copy()

# Add week start and end dates
df_sku_weekly['Week_Start'] = df_sku_weekly['Week']
df_sku_weekly['Week_End'] = df_sku_weekly['Week_Start'] + pd.Timedelta(days=6)

# -----------------------
# Split Test & Train
# -----------------------

# Test Data: June 2025
test_data = df_sku_weekly[
    (df_sku_weekly['Week_Start'] >= pd.to_datetime('2025-06-01')) &
    (df_sku_weekly['Week_Start'] < pd.to_datetime('2025-07-01'))
]

# Train Data: Before June 2025
train_data = df_sku_weekly[
    df_sku_weekly['Week_Start'] < pd.to_datetime('2025-06-01')
]


# -----------------------
# TRAIN DATA RANGE INFO
# -----------------------
# STEP 0: Print Training & Testing Period Info
train_start = train_data['Week_Start'].min()
train_end = train_data['Week_Start'].max()
test_start = test_data['Week_Start'].min()
test_end = test_data['Week_Start'].max()

# Compute durations
train_months = (train_end.to_period('M') - train_start.to_period('M')).n + 1
train_years = (train_end.to_period('Y') - train_start.to_period('Y')).n + 1
train_weeks = train_data['Week_Start'].nunique()

test_months = (test_end.to_period('M') - test_start.to_period('M')).n + 1
test_years = (test_end.to_period('Y') - test_start.to_period('Y')).n + 1
test_weeks = test_data['Week_Start'].nunique()

print(f"\nTraining Data Range: {train_start.date()} to {train_end.date()}")
print(f" - Total Years:  {train_years}")
print(f" - Total Months: {train_months}")
print(f" - Total Weeks:  {train_weeks}")

print(f"\nTesting Data Range:  {test_start.date()} to {test_end.date()}")
print(f" - Total Years:  {test_years}")
print(f" - Total Months: {test_months}")
print(f" - Total Weeks:  {test_weeks}")


print("\nTrain Data:")
print(train_data[['Week_Start', 'Week_End', 'WareHouseQuantity']].head(-1))

print("\nTest Data:")
print(test_data[['Week_Start', 'Week_End', 'WareHouseQuantity']].head(-1))
# Out:
# Training Data Range: 2022-09-12 to 2025-05-26
#  - Total Years:  4
#  - Total Months: 33
#  - Total Weeks:  139
#
# Testing Data Range:  2025-06-02 to 2025-06-30
#  - Total Years:  1
#  - Total Months: 1
#  - Total Weeks:  5
#
# Train Data:
#      Week_Start   Week_End  WareHouseQuantity
# 786  2022-09-12 2022-09-18                  1
# 801  2022-09-26 2022-10-02                  5
# 821  2022-10-17 2022-10-23                 17
# 831  2022-10-24 2022-10-30                 84
# 842  2022-10-31 2022-11-06                125
# ...         ...        ...                ...
# 1968 2025-04-21 2025-04-27                541
# 1978 2025-04-28 2025-05-04                509
# 1987 2025-05-05 2025-05-11                506
# 1996 2025-05-12 2025-05-18                486
# 2005 2025-05-19 2025-05-25                318
#
# [138 rows x 3 columns]
#
# Test Data:
#      Week_Start   Week_End  WareHouseQuantity
# 2027 2025-06-02 2025-06-08                375
# 2037 2025-06-09 2025-06-15                474
# 2047 2025-06-16 2025-06-22                475
# 2056 2025-06-23 2025-06-29                390

# %%
df.columns
# Out:
# Index(['ProductFamily', 'Order_ID', 'OrderDate', 'SKU_Description',
#        'WareHouseQuantity', 'SKU', 'SKU_Category', 'Channel', 'ShipToState',
#        'Week', 'Month', 'Year'],
#       dtype='object')

# %% [markdown]
# ### LSTM Model

# %%
# pip install tensorflow

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# ----- STEP 1: Prepare Data -----
# Assume train_data and test_data are already defined with columns ['Week_Start', 'Week_End', 'WareHouseQuantity']
df = pd.concat([train_data, test_data]).reset_index(drop=True)

# Normalize target column
scaler = MinMaxScaler()
scaled_quantity = scaler.fit_transform(df[['WareHouseQuantity']])

# ----- STEP 2: Create Sequences -----
def create_sequences(data, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i+sequence_length])
        y.append(data[i+sequence_length])
    return np.array(X), np.array(y)

sequence_length = 4
X_all, y_all = create_sequences(scaled_quantity, sequence_length)

# Align time indexes
time_data = df.iloc[sequence_length:].reset_index(drop=True)
X_train = X_all[:len(train_data) - sequence_length]
y_train = y_all[:len(train_data) - sequence_length]
X_test = X_all[len(train_data) - sequence_length:]
y_test = y_all[len(train_data) - sequence_length:]

# Reshape for LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# ----- STEP 3: Build LSTM Model -----
model = Sequential()
model.add(LSTM(128, input_shape=(X_train.shape[1], 1), return_sequences=False))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# ----- STEP 4: Train -----
model.fit(X_train, y_train, epochs=200, batch_size=8, verbose=1)

# ----- STEP 5: Predict -----
y_pred_scaled = model.predict(X_test)
y_pred = scaler.inverse_transform(y_pred_scaled)
y_true = scaler.inverse_transform(y_test)

# ----- STEP 6: Evaluation -----
print("MAE:", mean_absolute_error(y_true, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_true, y_pred)))
print("R2 Score:", r2_score(y_true, y_pred))

# ----- STEP 7: Result DataFrame -----
# Extract Start and End week for each prediction
start_weeks = test_data['Week_Start'].iloc[:len(y_true)].reset_index(drop=True)
end_weeks = test_data['Week_End'].iloc[:len(y_true)].reset_index(drop=True)

actuals = pd.Series(y_true.flatten()).reset_index(drop=True)
predicted = pd.Series(np.round(y_pred.flatten()).astype(int)).reset_index(drop=True)
difference = predicted - actuals
percent_diff = ((difference / actuals) * 100).round(2)
minus_10 = (actuals * 0.9).round(2)
plus_10 = (actuals * 1.1).round(2)
within_10 = (predicted >= minus_10) & (predicted <= plus_10)
status = within_10.map({True: "Acceptable", False: "Out of Range"})



result_df = pd.DataFrame({
    'Start_Week': start_weeks,
    'End_Week': end_weeks,
    'Actual_WareHouseQuantity': actuals,
    'Predicted_WareHouseQuantity': predicted,
    'Difference_Between_Predicted_And_Actual': difference,
    'Percent_Difference': percent_diff,
    'Minus_10_Percent': minus_10,
    'Plus_10_Percent': plus_10,
    'Within_10_Percent': status
})
# Accuracy within ±10% band
accuracy_within_10_percent = (result_df['Within_10_Percent'] == 'Acceptable').mean() * 100
print(f"\nAccuracy within ±10% of predicted values: {accuracy_within_10_percent:.2f}%")
print(result_df.head())

# ----- Optional: Save to CSV -----
# result_df.to_csv('lstm_forecast_results.csv', index=False)
result_df
# Out:
# Epoch 1/200
# c:\forecasting\workspace2\forecasting\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0293
# Epoch 2/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0205
# Epoch 3/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185
# Epoch 4/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181
# Epoch 5/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175
# Epoch 6/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0167
# Epoch 7/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0161
# Epoch 8/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0155
# Epoch 9/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0149
# Epoch 10/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0144
# Epoch 11/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0139
# Epoch 12/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0135
# Epoch 13/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0132
# Epoch 14/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0130
# Epoch 15/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0128
# Epoch 16/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0125
# Epoch 17/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0123
# Epoch 18/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0121
# Epoch 19/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0120
# Epoch 20/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0119
# Epoch 21/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0117
# Epoch 22/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0116
# Epoch 23/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0115
# Epoch 24/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0115
# Epoch 25/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0114
# Epoch 26/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0113
# Epoch 27/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0113
# Epoch 28/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0112
# Epoch 29/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0112
# Epoch 30/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0112
# Epoch 31/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0111
# Epoch 32/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0111
# Epoch 33/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0110
# Epoch 34/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0110
# Epoch 35/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0110
# Epoch 36/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0109
# Epoch 37/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0109
# Epoch 38/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0109
# Epoch 39/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0109
# Epoch 40/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0109
# Epoch 41/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0109
# Epoch 42/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0108
# Epoch 43/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0108
# Epoch 44/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0108
# Epoch 45/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0108
# Epoch 46/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0108
# Epoch 47/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0107
# Epoch 48/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0107
# Epoch 49/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0108
# Epoch 50/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0107
# Epoch 51/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0107
# Epoch 52/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0106
# Epoch 53/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0106
# Epoch 54/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0106
# Epoch 55/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0105
# Epoch 56/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0105
# Epoch 57/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0105
# Epoch 58/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0104
# Epoch 59/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0104
# Epoch 60/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0104
# Epoch 61/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0104
# Epoch 62/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0104
# Epoch 63/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0104
# Epoch 64/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103
# Epoch 65/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0104
# Epoch 66/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103
# Epoch 67/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0104
# Epoch 68/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103
# Epoch 69/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103
# Epoch 70/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103
# Epoch 71/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103
# Epoch 72/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102
# Epoch 73/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102
# Epoch 74/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102
# Epoch 75/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102
# Epoch 76/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102
# Epoch 77/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102
# Epoch 78/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102
# Epoch 79/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102
# Epoch 80/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102
# Epoch 81/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102
# Epoch 82/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102
# Epoch 83/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101
# Epoch 84/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101
# Epoch 85/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101
# Epoch 86/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101
# Epoch 87/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101
# Epoch 88/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101
# Epoch 89/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100
# Epoch 90/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100
# Epoch 91/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100
# Epoch 92/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100
# Epoch 93/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100
# Epoch 94/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100
# Epoch 95/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100
# Epoch 96/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101
# Epoch 97/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100
# Epoch 98/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100
# Epoch 99/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 100/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100
# Epoch 101/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 102/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100
# Epoch 103/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 104/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 105/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 106/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 107/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 108/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 109/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 110/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 111/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 112/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 113/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 114/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 115/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0098
# Epoch 116/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 117/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0098
# Epoch 118/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0098
# Epoch 119/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0098
# Epoch 120/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0098
# Epoch 121/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0098
# Epoch 122/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097
# Epoch 123/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0098
# Epoch 124/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0098
# Epoch 125/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0098
# Epoch 126/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 127/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097
# Epoch 128/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0098
# Epoch 129/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097
# Epoch 130/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 131/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097
# Epoch 132/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0097
# Epoch 133/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096
# Epoch 134/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096
# Epoch 135/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097
# Epoch 136/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095
# Epoch 137/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096
# Epoch 138/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097
# Epoch 139/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096
# Epoch 140/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095
# Epoch 141/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097
# Epoch 142/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095
# Epoch 143/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096
# Epoch 144/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095
# Epoch 145/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095
# Epoch 146/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094
# Epoch 147/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095
# Epoch 148/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094
# Epoch 149/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096
# Epoch 150/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094
# Epoch 151/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095
# Epoch 152/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093
# Epoch 153/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095
# Epoch 154/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093
# Epoch 155/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0094
# Epoch 156/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092
# Epoch 157/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093
# Epoch 158/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093
# Epoch 159/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092
# Epoch 160/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092
# Epoch 161/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093
# Epoch 162/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092
# Epoch 163/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092
# Epoch 164/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0090
# Epoch 165/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091
# Epoch 166/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092
# Epoch 167/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094
# Epoch 168/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093
# Epoch 169/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093
# Epoch 170/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094
# Epoch 171/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093
# Epoch 172/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094
# Epoch 173/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091
# Epoch 174/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093
# Epoch 175/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089
# Epoch 176/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091
# Epoch 177/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0090
# Epoch 178/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093
# Epoch 179/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0090
# Epoch 180/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092
# Epoch 181/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089
# Epoch 182/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094
# Epoch 183/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088
# Epoch 184/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091
# Epoch 185/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0087
# Epoch 186/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093
# Epoch 187/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088
# Epoch 188/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092
# Epoch 189/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088
# Epoch 190/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0093
# Epoch 191/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0087
# Epoch 192/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089
# Epoch 193/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085
# Epoch 194/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088
# Epoch 195/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083
# Epoch 196/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088
# Epoch 197/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0082
# Epoch 198/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0087
# Epoch 199/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083
# Epoch 200/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001D7492D4680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# MAE: 97.13890380859375
# RMSE: 109.5174767607038
# R2 Score: -5.064230532313684
#
# Accuracy within ±10% of predicted values: 20.00%
#   Start_Week   End_Week  Actual_WareHouseQuantity  \
# 0 2025-06-02 2025-06-08                     375.0
# 1 2025-06-09 2025-06-15                     474.0
# 2 2025-06-16 2025-06-22                     475.0
# 3 2025-06-23 2025-06-29                     390.0
# 4 2025-06-30 2025-07-06                     388.0
#
#    Predicted_WareHouseQuantity  Difference_Between_Predicted_And_Actual  \
# 0                          517                                    142.0
# 1                          461                                    -13.0
# 2                          555                                     80.0
# 3                          545                                    155.0
# 4                          484                                     96.0
#
#    Percent_Difference  Minus_10_Percent  Plus_10_Percent Within_10_Percent
# 0               37.87             337.5            412.5      Out of Range
# 1               -2.74             426.6            521.4        Acceptable
# 2               16.84             427.5            522.5      Out of Range
# 3               39.74             351.0            429.0      Out of Range
# 4               24.74             349.2            426.8      Out of Range
#   Start_Week   End_Week  Actual_WareHouseQuantity  \
# 0 2025-06-02 2025-06-08                     375.0
# 1 2025-06-09 2025-06-15                     474.0
# 2 2025-06-16 2025-06-22                     475.0
# 3 2025-06-23 2025-06-29                     390.0
# 4 2025-06-30 2025-07-06                     388.0
#
#    Predicted_WareHouseQuantity  Difference_Between_Predicted_And_Actual  \
# 0                          517                                    142.0
# 1                          461                                    -13.0
# 2                          555                                     80.0
# 3                          545                                    155.0
# 4                          484                                     96.0
#
#    Percent_Difference  Minus_10_Percent  Plus_10_Percent Within_10_Percent
# 0               37.87             337.5            412.5      Out of Range
# 1               -2.74             426.6            521.4        Acceptable
# 2               16.84             427.5            522.5      Out of Range
# 3               39.74             351.0            429.0      Out of Range
# 4               24.74             349.2            426.8      Out of Range

# %% [markdown]
# ### Used metrics=['mae']

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# ----- STEP 1: Prepare Data -----
df = pd.concat([train_data, test_data]).reset_index(drop=True)

# Normalize target column
scaler = MinMaxScaler()
scaled_quantity = scaler.fit_transform(df[['WareHouseQuantity']])

# ----- STEP 2: Create Sequences -----
def create_sequences(data, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i+sequence_length])
        y.append(data[i+sequence_length])
    return np.array(X), np.array(y)

sequence_length = 4
X_all, y_all = create_sequences(scaled_quantity, sequence_length)

# Align time indexes
time_data = df.iloc[sequence_length:].reset_index(drop=True)
X_train = X_all[:len(train_data) - sequence_length]
y_train = y_all[:len(train_data) - sequence_length]
X_test = X_all[len(train_data) - sequence_length:]
y_test = y_all[len(train_data) - sequence_length:]

# Reshape for LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# ----- STEP 3: Build LSTM Model -----
model = Sequential()
model.add(LSTM(128, input_shape=(X_train.shape[1], 1)))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae'])

# ----- STEP 4: Train -----
model.fit(X_train, y_train, epochs=200, batch_size=8, verbose=1)

# ----- STEP 5: Predict -----
y_pred_scaled = model.predict(X_test)
y_pred = scaler.inverse_transform(y_pred_scaled)
y_true = scaler.inverse_transform(y_test.reshape(-1, 1))

# ----- STEP 6: Evaluation -----
print("MAE:", mean_absolute_error(y_true, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_true, y_pred)))
print("R2 Score:", r2_score(y_true, y_pred))

# ----- STEP 7: Result DataFrame -----
start_weeks = test_data['Week_Start'].iloc[:len(y_true)].reset_index(drop=True)
end_weeks = test_data['Week_End'].iloc[:len(y_true)].reset_index(drop=True)

actuals = pd.Series(y_true.flatten()).reset_index(drop=True)
predicted = pd.Series(np.round(y_pred.flatten()).astype(int)).reset_index(drop=True)
difference = predicted - actuals
percent_diff = ((difference / actuals) * 100).round(2)
minus_10 = (actuals * 0.9).round(2)
plus_10 = (actuals * 1.1).round(2)
within_10 = (predicted >= minus_10) & (predicted <= plus_10)
status = within_10.map({True: "Acceptable", False: "Out of Range"})

result_df = pd.DataFrame({
    'Start_Week': start_weeks,
    'End_Week': end_weeks,
    'Actual_WareHouseQuantity': actuals,
    'Predicted_WareHouseQuantity': predicted,
    'Difference_Between_Predicted_And_Actual': difference,
    'Percent_Difference': percent_diff,
    'Minus_10_Percent': minus_10,
    'Plus_10_Percent': plus_10,
    'Within_10_Percent': status
})

# ----- Accuracy within ±10% Band -----
accuracy_within_10_percent = (result_df['Within_10_Percent'] == 'Acceptable').mean() * 100
print(f"\nAccuracy within ±10% of predicted values: {accuracy_within_10_percent:.2f}%")

# ----- Output -----
# print(result_df.head())
# result_df.to_csv('lstm_forecast_results.csv', index=False)
result_df
# Out:
# Epoch 1/200
# c:\forecasting\workspace2\forecasting\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0348 - mae: 0.1327
# Epoch 2/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0216 - mae: 0.1046
# Epoch 3/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - mae: 0.0919
# Epoch 4/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0191 - mae: 0.0948
# Epoch 5/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0185 - mae: 0.0915
# Epoch 6/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180 - mae: 0.0912
# Epoch 7/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0175 - mae: 0.0896
# Epoch 8/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0170 - mae: 0.0883
# Epoch 9/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164 - mae: 0.0863
# Epoch 10/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0158 - mae: 0.0839
# Epoch 11/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0155 - mae: 0.0840
# Epoch 12/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0148 - mae: 0.0830
# Epoch 13/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0140 - mae: 0.0808
# Epoch 14/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0135 - mae: 0.0791
# Epoch 15/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0132 - mae: 0.0781
# Epoch 16/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0129 - mae: 0.0769
# Epoch 17/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0127 - mae: 0.0762
# Epoch 18/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0124 - mae: 0.0748
# Epoch 19/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0122 - mae: 0.0737
# Epoch 20/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0121 - mae: 0.0733
# Epoch 21/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0119 - mae: 0.0723
# Epoch 22/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0117 - mae: 0.0717
# Epoch 23/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0115 - mae: 0.0706
# Epoch 24/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0114 - mae: 0.0701
# Epoch 25/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0113 - mae: 0.0700
# Epoch 26/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0112 - mae: 0.0693
# Epoch 27/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0111 - mae: 0.0689
# Epoch 28/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0111 - mae: 0.0687
# Epoch 29/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0110 - mae: 0.0683
# Epoch 30/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0109 - mae: 0.0680
# Epoch 31/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0108 - mae: 0.0678
# Epoch 32/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0108 - mae: 0.0675
# Epoch 33/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0107 - mae: 0.0673
# Epoch 34/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0107 - mae: 0.0668
# Epoch 35/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0107 - mae: 0.0668
# Epoch 36/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0106 - mae: 0.0668
# Epoch 37/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0106 - mae: 0.0667
# Epoch 38/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0106 - mae: 0.0668
# Epoch 39/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0106 - mae: 0.0666
# Epoch 40/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0105 - mae: 0.0663
# Epoch 41/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0105 - mae: 0.0663
# Epoch 42/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0105 - mae: 0.0665
# Epoch 43/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0105 - mae: 0.0664
# Epoch 44/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0104 - mae: 0.0661
# Epoch 45/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0104 - mae: 0.0661
# Epoch 46/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0104 - mae: 0.0661
# Epoch 47/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0104 - mae: 0.0663
# Epoch 48/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0104 - mae: 0.0661
# Epoch 49/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0103 - mae: 0.0660
# Epoch 50/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103 - mae: 0.0661
# Epoch 51/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0104 - mae: 0.0663
# Epoch 52/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0103 - mae: 0.0664
# Epoch 53/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0103 - mae: 0.0663
# Epoch 54/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103 - mae: 0.0661
# Epoch 55/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103 - mae: 0.0660
# Epoch 56/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102 - mae: 0.0654
# Epoch 57/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102 - mae: 0.0655
# Epoch 58/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0102 - mae: 0.0655
# Epoch 59/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - mae: 0.0655
# Epoch 60/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - mae: 0.0651
# Epoch 61/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - mae: 0.0652
# Epoch 62/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - mae: 0.0650
# Epoch 63/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - mae: 0.0650
# Epoch 64/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0101 - mae: 0.0655
# Epoch 65/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - mae: 0.0653
# Epoch 66/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - mae: 0.0661
# Epoch 67/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - mae: 0.0659
# Epoch 68/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - mae: 0.0662
# Epoch 69/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0100 - mae: 0.0659
# Epoch 70/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - mae: 0.0662
# Epoch 71/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - mae: 0.0659
# Epoch 72/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100 - mae: 0.0663
# Epoch 73/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - mae: 0.0667
# Epoch 74/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0101 - mae: 0.0662
# Epoch 75/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0099 - mae: 0.0648
# Epoch 76/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099 - mae: 0.0654
# Epoch 77/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099 - mae: 0.0653
# Epoch 78/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099 - mae: 0.0659
# Epoch 79/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0100 - mae: 0.0658
# Epoch 80/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0099 - mae: 0.0664
# Epoch 81/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100 - mae: 0.0662
# Epoch 82/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100 - mae: 0.0665
# Epoch 83/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0100 - mae: 0.0663
# Epoch 84/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0100 - mae: 0.0667
# Epoch 85/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100 - mae: 0.0670
# Epoch 86/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100 - mae: 0.0658
# Epoch 87/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - mae: 0.0646
# Epoch 88/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - mae: 0.0645
# Epoch 89/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096 - mae: 0.0646
# Epoch 90/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - mae: 0.0646
# Epoch 91/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096 - mae: 0.0648
# Epoch 92/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - mae: 0.0646
# Epoch 93/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - mae: 0.0653
# Epoch 94/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099 - mae: 0.0652
# Epoch 95/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096 - mae: 0.0651
# Epoch 96/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - mae: 0.0649
# Epoch 97/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096 - mae: 0.0651
# Epoch 98/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096 - mae: 0.0648
# Epoch 99/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096 - mae: 0.0648
# Epoch 100/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095 - mae: 0.0648
# Epoch 101/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - mae: 0.0649
# Epoch 102/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095 - mae: 0.0644
# Epoch 103/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - mae: 0.0647
# Epoch 104/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0095 - mae: 0.0645
# Epoch 105/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096 - mae: 0.0644
# Epoch 106/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095 - mae: 0.0650
# Epoch 107/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - mae: 0.0656
# Epoch 108/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0095 - mae: 0.0646
# Epoch 109/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095 - mae: 0.0641
# Epoch 110/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094 - mae: 0.0641
# Epoch 111/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094 - mae: 0.0639
# Epoch 112/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - mae: 0.0641
# Epoch 113/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094 - mae: 0.0640
# Epoch 114/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095 - mae: 0.0650
# Epoch 115/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099 - mae: 0.0664
# Epoch 116/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096 - mae: 0.0653
# Epoch 117/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096 - mae: 0.0649
# Epoch 118/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093 - mae: 0.0639
# Epoch 119/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093 - mae: 0.0640
# Epoch 120/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092 - mae: 0.0639
# Epoch 121/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0092 - mae: 0.0639
# Epoch 122/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0092 - mae: 0.0641
# Epoch 123/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - mae: 0.0635
# Epoch 124/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091 - mae: 0.0642
# Epoch 125/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091 - mae: 0.0635
# Epoch 126/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091 - mae: 0.0643
# Epoch 127/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091 - mae: 0.0638
# Epoch 128/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093 - mae: 0.0654
# Epoch 129/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093 - mae: 0.0642
# Epoch 130/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091 - mae: 0.0649
# Epoch 131/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092 - mae: 0.0636
# Epoch 132/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089 - mae: 0.0639
# Epoch 133/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092 - mae: 0.0651
# Epoch 134/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091 - mae: 0.0656
# Epoch 135/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0090 - mae: 0.0639
# Epoch 136/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0087 - mae: 0.0635
# Epoch 137/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088 - mae: 0.0630
# Epoch 138/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0086 - mae: 0.0625
# Epoch 139/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0088 - mae: 0.0639
# Epoch 140/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089 - mae: 0.0633
# Epoch 141/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093 - mae: 0.0666
# Epoch 142/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092 - mae: 0.0636
# Epoch 143/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089 - mae: 0.0647
# Epoch 144/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0087 - mae: 0.0619
# Epoch 145/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085 - mae: 0.0635
# Epoch 146/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0087 - mae: 0.0629
# Epoch 147/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093 - mae: 0.0680
# Epoch 148/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089 - mae: 0.0633
# Epoch 149/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0086 - mae: 0.0637
# Epoch 150/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084 - mae: 0.0609
# Epoch 151/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0086 - mae: 0.0632
# Epoch 152/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084 - mae: 0.0604
# Epoch 153/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085 - mae: 0.0638
# Epoch 154/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085 - mae: 0.0613
# Epoch 155/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0086 - mae: 0.0648
# Epoch 156/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085 - mae: 0.0613
# Epoch 157/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0082 - mae: 0.0615
# Epoch 158/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0081 - mae: 0.0599
# Epoch 159/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0083 - mae: 0.0633
# Epoch 160/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084 - mae: 0.0612
# Epoch 161/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083 - mae: 0.0626
# Epoch 162/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0082 - mae: 0.0606
# Epoch 163/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - mae: 0.0620
# Epoch 164/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0080 - mae: 0.0593
# Epoch 165/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - mae: 0.0623
# Epoch 166/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0080 - mae: 0.0594
# Epoch 167/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0080 - mae: 0.0614
# Epoch 168/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - mae: 0.0604
# Epoch 169/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - mae: 0.0626
# Epoch 170/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - mae: 0.0603
# Epoch 171/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - mae: 0.0624
# Epoch 172/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - mae: 0.0595
# Epoch 173/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - mae: 0.0627
# Epoch 174/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - mae: 0.0593
# Epoch 175/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084 - mae: 0.0646
# Epoch 176/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0079 - mae: 0.0602
# Epoch 177/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0077 - mae: 0.0602
# Epoch 178/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - mae: 0.0589
# Epoch 179/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0078 - mae: 0.0616
# Epoch 180/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0077 - mae: 0.0591
# Epoch 181/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - mae: 0.0603
# Epoch 182/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - mae: 0.0577
# Epoch 183/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0079 - mae: 0.0625
# Epoch 184/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0076 - mae: 0.0591
# Epoch 185/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0076 - mae: 0.0595
# Epoch 186/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - mae: 0.0572
# Epoch 187/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - mae: 0.0604
# Epoch 188/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - mae: 0.0578
# Epoch 189/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - mae: 0.0623
# Epoch 190/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - mae: 0.0580
# Epoch 191/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - mae: 0.0626
# Epoch 192/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - mae: 0.0572
# Epoch 193/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0076 - mae: 0.0611
# Epoch 194/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - mae: 0.0582
# Epoch 195/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - mae: 0.0588
# Epoch 196/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - mae: 0.0565
# Epoch 197/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - mae: 0.0589
# Epoch 198/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - mae: 0.0569
# Epoch 199/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - mae: 0.0597
# Epoch 200/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - mae: 0.0576
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001D759B56020> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# MAE: 118.025390625
# RMSE: 127.40621180181748
# R2 Score: -7.207106138863393
#
# Accuracy within ±10% of predicted values: 0.00%
#   Start_Week   End_Week  Actual_WareHouseQuantity  \
# 0 2025-06-02 2025-06-08                     375.0
# 1 2025-06-09 2025-06-15                     474.0
# 2 2025-06-16 2025-06-22                     475.0
# 3 2025-06-23 2025-06-29                     390.0
# 4 2025-06-30 2025-07-06                     388.0
#
#    Predicted_WareHouseQuantity  Difference_Between_Predicted_And_Actual  \
# 0                          541                                    166.0
# 1                          541                                     67.0
# 2                          546                                     71.0
# 3                          573                                    183.0
# 4                          492                                    104.0
#
#    Percent_Difference  Minus_10_Percent  Plus_10_Percent Within_10_Percent
# 0               44.27             337.5            412.5      Out of Range
# 1               14.14             426.6            521.4      Out of Range
# 2               14.95             427.5            522.5      Out of Range
# 3               46.92             351.0            429.0      Out of Range
# 4               26.80             349.2            426.8      Out of Range

# %% [markdown]
# #### Actual vs Predicted

# %%
plt.figure(figsize=(12, 6))
plt.plot(result_df['Start_Week'], result_df['Actual_WareHouseQuantity'], label='Actual', marker='o')
plt.plot(result_df['Start_Week'], result_df['Predicted_WareHouseQuantity'], label='Predicted', marker='x')
plt.xticks(rotation=45)
plt.title('LSTM Forecasting: Actual vs Predicted')
plt.xlabel('Week')
plt.ylabel('WareHouseQuantity')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Using `activation='mish', batch_size=64, sequence_length=18`

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import random
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

# ----------------------- STEP 0: Set Random Seed -----------------------
def set_seed(seed=42):
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)

set_seed(42)

# ----------------------- STEP 1: Prepare Data -----------------------
df = pd.concat([train_data, test_data]).reset_index(drop=True)

# Normalize target
scaler = MinMaxScaler()
scaled_quantity = scaler.fit_transform(df[['WareHouseQuantity']])

# ----------------------- STEP 2: Create Sequences -----------------------
def create_sequences(data, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i+sequence_length])
        y.append(data[i+sequence_length])
    return np.array(X), np.array(y)

sequence_length = 10
X_all, y_all = create_sequences(scaled_quantity, sequence_length)

X_train = X_all[:len(train_data) - sequence_length]
y_train = y_all[:len(train_data) - sequence_length]
X_test = X_all[len(train_data) - sequence_length:]
y_test = y_all[len(train_data) - sequence_length:]

# Reshape for LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# ----------------------- STEP 3: Build Model -----------------------
model = Sequential()
model.add(LSTM(192, input_shape=(sequence_length, 1)))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))  # Linear activation for regression

# ----------------------- STEP 4: Compile -----------------------
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# ----------------------- STEP 5: Callbacks -----------------------
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=10, factor=0.5, min_lr=1e-6, verbose=1)

# ----------------------- STEP 6: Train Model -----------------------
history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=16,
    validation_split=0.1,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

# ----------------------- STEP 7: Predict -----------------------
y_pred_scaled = model.predict(X_test, verbose=0)
y_pred = scaler.inverse_transform(y_pred_scaled)
y_true = scaler.inverse_transform(y_test.reshape(-1, 1))

# ----------------------- STEP 8: Evaluation -----------------------
print("MAE:", mean_absolute_error(y_true, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_true, y_pred)))
print("R2 Score:", r2_score(y_true, y_pred))

# ----------------------- STEP 9: Result DataFrame -----------------------
start_weeks = test_data['Week_Start'].iloc[:len(y_true)].reset_index(drop=True)
end_weeks = test_data['Week_End'].iloc[:len(y_true)].reset_index(drop=True)

actuals = pd.Series(y_true.flatten()).reset_index(drop=True)
predicted = pd.Series(np.round(y_pred.flatten()).astype(int)).reset_index(drop=True)
difference = predicted - actuals
percent_diff = ((difference / actuals) * 100).round(2)
minus_10 = (actuals * 0.9).round(2)
plus_10 = (actuals * 1.1).round(2)
within_10 = (predicted >= minus_10) & (predicted <= plus_10)
status = within_10.map({True: "Acceptable", False: "Out of Range"})

result_df = pd.DataFrame({
    'Start_Week': start_weeks,
    'End_Week': end_weeks,
    'Actual_WareHouseQuantity': actuals,
    'Predicted_WareHouseQuantity': predicted,
    'Difference_Between_Predicted_And_Actual': difference,
    'Percent_Difference': percent_diff,
    'Minus_10_Percent': minus_10,
    'Plus_10_Percent': plus_10,
    'Within_10_Percent': status
})

accuracy_within_10 = (result_df['Within_10_Percent'] == 'Acceptable').mean() * 100
print(f"\nAccuracy within ±10% of predicted values: {accuracy_within_10:.2f}%")

# Optionally save model and results
# model.save("best_lstm_model.h5")
# result_df.to_csv("best_model_results.csv", index=False)

# Return result
result_df
# Out:
# Epoch 1/200
# c:\forecasting\workspace2\forecasting\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0576 - mae: 0.1803 - val_loss: 0.0154 - val_mae: 0.1182 - learning_rate: 1.0000e-04
# Epoch 2/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0441 - mae: 0.1435 - val_loss: 0.0077 - val_mae: 0.0792 - learning_rate: 1.0000e-04
# Epoch 3/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0339 - mae: 0.1135 - val_loss: 0.0029 - val_mae: 0.0441 - learning_rate: 1.0000e-04
# Epoch 4/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0268 - mae: 0.0987 - val_loss: 0.0018 - val_mae: 0.0325 - learning_rate: 1.0000e-04
# Epoch 5/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0234 - mae: 0.0998 - val_loss: 0.0038 - val_mae: 0.0511 - learning_rate: 1.0000e-04
# Epoch 6/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0227 - mae: 0.1056 - val_loss: 0.0055 - val_mae: 0.0637 - learning_rate: 1.0000e-04
# Epoch 7/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0226 - mae: 0.1083 - val_loss: 0.0053 - val_mae: 0.0623 - learning_rate: 1.0000e-04
# Epoch 8/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0223 - mae: 0.1063 - val_loss: 0.0044 - val_mae: 0.0559 - learning_rate: 1.0000e-04
# Epoch 9/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0220 - mae: 0.1041 - val_loss: 0.0039 - val_mae: 0.0527 - learning_rate: 1.0000e-04
# Epoch 10/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0219 - mae: 0.1031 - val_loss: 0.0037 - val_mae: 0.0520 - learning_rate: 1.0000e-04
# Epoch 11/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0218 - mae: 0.1029 - val_loss: 0.0038 - val_mae: 0.0527 - learning_rate: 1.0000e-04
# Epoch 12/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0217 - mae: 0.1031 - val_loss: 0.0039 - val_mae: 0.0534 - learning_rate: 1.0000e-04
# Epoch 13/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0216 - mae: 0.1032 - val_loss: 0.0038 - val_mae: 0.0534 - learning_rate: 1.0000e-04
# Epoch 14/200
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0064 - mae: 0.0665
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0215 - mae: 0.1031 - val_loss: 0.0038 - val_mae: 0.0530 - learning_rate: 1.0000e-04
# Epoch 15/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0214 - mae: 0.1027 - val_loss: 0.0037 - val_mae: 0.0528 - learning_rate: 5.0000e-05
# Epoch 16/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0214 - mae: 0.1026 - val_loss: 0.0037 - val_mae: 0.0527 - learning_rate: 5.0000e-05
# Epoch 17/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0213 - mae: 0.1026 - val_loss: 0.0037 - val_mae: 0.0526 - learning_rate: 5.0000e-05
# Epoch 18/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0213 - mae: 0.1025 - val_loss: 0.0036 - val_mae: 0.0525 - learning_rate: 5.0000e-05
# Epoch 19/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0212 - mae: 0.1024 - val_loss: 0.0036 - val_mae: 0.0524 - learning_rate: 5.0000e-05
# Epoch 20/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0212 - mae: 0.1023 - val_loss: 0.0036 - val_mae: 0.0523 - learning_rate: 5.0000e-05
# Epoch 21/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0212 - mae: 0.1022 - val_loss: 0.0036 - val_mae: 0.0521 - learning_rate: 5.0000e-05
# Epoch 22/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0211 - mae: 0.1022 - val_loss: 0.0035 - val_mae: 0.0521 - learning_rate: 5.0000e-05
# Epoch 23/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0211 - mae: 0.1021 - val_loss: 0.0035 - val_mae: 0.0520 - learning_rate: 5.0000e-05
# Epoch 24/200
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0064 - mae: 0.0660
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0210 - mae: 0.1020 - val_loss: 0.0035 - val_mae: 0.0518 - learning_rate: 5.0000e-05
# MAE: 45.22357177734375
# RMSE: 48.00653169414846
# R2 Score: -0.1652242270867612
#
# Accuracy within ±10% of predicted values: 80.00%
#   Start_Week   End_Week  Actual_WareHouseQuantity  \
# 0 2025-06-02 2025-06-08                     375.0
# 1 2025-06-09 2025-06-15                     474.0
# 2 2025-06-16 2025-06-22                     475.0
# 3 2025-06-23 2025-06-29                     390.0
# 4 2025-06-30 2025-07-06                     388.0
#
#    Predicted_WareHouseQuantity  Difference_Between_Predicted_And_Actual  \
# 0                          452                                     77.0
# 1                          436                                    -38.0
# 2                          433                                    -42.0
# 3                          425                                     35.0
# 4                          422                                     34.0
#
#    Percent_Difference  Minus_10_Percent  Plus_10_Percent Within_10_Percent
# 0               20.53             337.5            412.5      Out of Range
# 1               -8.02             426.6            521.4        Acceptable
# 2               -8.84             427.5            522.5        Acceptable
# 3                8.97             351.0            429.0        Acceptable
# 4                8.76             349.2            426.8        Acceptable
